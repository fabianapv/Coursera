# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Exercise 2: Create a markdown cell with the title of the notebook.
# Final proyect: Introduction to Data Science
#
# Exercise 3: Create a markdown cell for an introduction.
# Introduction: This notebook contains basic information about Data Science, including commonly used languages, popular libraries, and tools. It also includes examples of arithmetic operations in Python.
#
# Exercise 4: Create a markdown cell to list data science languages.
# - Python
# - R
# - SQL
# - Julia
# - Scala
#
# Exercise 5: Create a markdown cell to list data science libraries.
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
#
# Exercise 6: Create a markdown cell with a table of Data Science tools.
# | Tool                   | Description |
# |------------------------|-------------|
# | Jupyter Notebook       | Interactive environment for Python programming |
# | RStudio               | Development environment for R |
# | Apache Spark          | Big data processing framework |
# | TensorFlow            | Machine learning library |
# | Power BI              | Data visualization platform |
#
# Exercise 7:  Create a markdown cell introducing arithmetic expression examples.
# - Addition: `2 + 3 = 5`
# - Subtraction: `7 - 2 = 5`
# - Multiplication: `4 * 5 = 20`
# - Division: `10 / 2 = 5.0`

# %%
print("Exercise 8: Create a code cell to multiply and add numbers.")
result = (5 * 3) + 2
print("The result is:", result)
# Out:
# Exercise 8: Create a code cell to multiply and add numbers.
# The result is: 17

# %%
print("Exercise 9: Create a code cell to convert minutes to hours.")
minutes = 120
hours = minutes/60
print(minutes, "minutes is equivalent to", hours, "hours")
# Out:
# Exercise 9: Create a code cell to convert minutes to hours.
# 120 minutes is equivalent to 2.0 hours

# %% [markdown]
# Exercise 10: Insert a markdown cell to list Objectives.
#
# Objectives:
# - Learn the fundamentals of Data Science
# - Familiarize with Jupyter Notebook
# - Practice arithmetic expressions in Python
# - Explore tools and libraries for Data Science
#
# Exercise 11: Create a markdown cell to indicate the Author’s name.
#
# Author's name: Fabián Parada Vargas
